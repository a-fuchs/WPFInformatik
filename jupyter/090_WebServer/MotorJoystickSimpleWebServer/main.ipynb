# %% [markdown]
# [Home](../index.ipynb) / Web-Server: Simple webserver with files
# ***

# %% [markdown]
# # Simple webserver with files

# %%
#%serialconnect --port=COM3 # Windows
%serialconnect # Linux or Windows with one COM port 

#######################################
# Constants

# ID_LED = 13 # Esp8266: Croduino 
ID_LED = 25 # Esp32 HeltTec
# ID_LED = 14 # Esp32 NodeMCU, external LED

#======================================
SSID        = "ESP minimal http-server"
PASSWORD    = '123123123123' # default is 'micropythoN', attension: at least 8 chars, otherwise error: 'OSError: can't set AP config'
MAX_CLIENTS = 5 # Good maximal ammount of posiible clients


POLL_TIME_MILLIS = 0

#######################################
# Init

from machine import PWM, Pin

led = PWM( Pin(25, Pin.OUT), freq=1000, duty=0)  # 25 HelTec, 13 Croduino


#======================================
# Typical code for setting up the controller as access point.
# At the end we get a server-socket listening for clients to connect:

import network
import socket # usocket
import select # uselect


wlanAccessPoint = network.WLAN( network.AP_IF ) # create access-point interface

wlanAccessPoint.config( essid = SSID, password = PASSWORD ) # ESP-8266 and ESP-32
# wlanAccessPoint.config( essid = SSID, password = PASSWORD, max_clients = MAX_CLIENTS ) # ESP32
    
wlanAccessPoint.active( True )  # activate the interface

print( wlanAccessPoint.ifconfig()[0] )

# A internet stream server-socket: this server-socket creates the clientSockets.
serverSocket = socket.socket( socket.AF_INET, socket.SOCK_STREAM )

# To prevent "OSError: [Errno 98] Address already in use",
# when a previous execution has left the socket in a TIME_WAIT state,
# and so can’t be immediately reused:

#   SOL_SOCKET:   Socket Options That Apply to the Socket Layer
#   SO_REUSEADDR: Indicates if the local socket address can be reused.
#                 This option is supported by sockets with an address family
#                 of AF_INET or AF_INET6 and a type of SOCK_STREAM or SOCK_DGRAM.
#   1:            A value of 0 (default) disables the option.
#                 A non-zero value sets the option indicating the local socket address can be reused.

serverSocket.setsockopt( socket.SOL_SOCKET, socket.SO_REUSEADDR, 1 )

try:
    serverSocket.bind( ( '', 80 ) ) # everyone can connect
    serverSocket.listen( MAX_CLIENTS )
except Exception as _e:
    print( _e )


# Register serverSocket for polling (POLLIN: only poll for input)
poll = select.poll()
poll.register( serverSocket, select.POLLIN )


#######################################
# Extract request-path from header:
# For example:
#   In browser:      "http://192.168.4.1/led/On"
#   ==> strRequest:  "GET /led/On"
#   This function removes the "GET " and returns in this example "/led/On".

def getPathFromRequest( strRequest ) :
    iRequestPathStart = strRequest.find( "GET " ) # Every http request starts with "GET "

    if iRequestPathStart >= 0 :                    # followed by the request-path delimited with a ' ' charakter.
        iRequestPathStart += 4

        iRequestPathEnd = strRequest.find( " ", iRequestPathStart )

        if iRequestPathEnd >= 0 :
            return strRequest[ iRequestPathStart : iRequestPathEnd ]

    return ""
    

def sendHttpHeader( strResponseType, strContentType, clientSocket ):
    clientSocket.send( "HTTP/1.1 " )
    clientSocket.send( strResponseType )
    clientSocket.send( "\nContent-Type: text/" )
    clientSocket.send( strContentType )
    clientSocket.send( "; charset=UTF-8\n" ) # we send html and text is encoded in UTF-8
    clientSocket.send( "Connection: close\n\n" ) # We are (suspending and) closing the connection after sending the data.

def sendFile( strFileName, clientSocket ):    
    with open( strFileName, 'r' ) as f:
        while True:
            chunk = f.read(1024) # Read the next 1KB chunk
            
            if not chunk:
                break
                
            clientSocket.send(chunk) # Send the next 1KB chunk
            
            
#######################################
# Loop
# Listen for connecting clients and
# handle requests
import time
import display
display = display.Display()
display.setCenter( 64, 32 )

import re

PATTERN_JOYSTICK = re.compile( "/joystick/(.*)_(.*)" )

fSpeed  = 0
fGear   = 0

from motor import Motor

motorL = Motor( 12, 13,
    iFrequency     = 300,
    iDutyMinLeft   = 220,
    iDutyMaxLeft   = 1023,
    iDutyMinRight  = 220,
    iDutyMaxRight  = 1023,
    fSpeedMaxLeft  = -1.0,
    fSpeedMaxRight =  1.0 )

motorR = Motor( 18, 22,
    iFrequency     = 300,
    iDutyMinLeft   = 220,
    iDutyMaxLeft   = 1023,
    iDutyMinRight  = 220,
    iDutyMaxRight  = 1023,
    fSpeedMaxLeft  = -1.0,
    fSpeedMaxRight =  1.0 )

try:
    while True:
        aEvent = poll.poll( POLL_TIME_MILLIS ) # wait POLL_TIME_MILLIS, then give other tasks a chanche, to do there work.
        
        # check if we have stuff to handle
        
        if aEvent:
            # Only serverSocket is registered for polling, so only this one can be in the list (aEvent)
            
            try:
                # The return value is a pair (clientSocket, clientAddress)
                # where clientSocket is a new socket object where we can
                # receive data from and send data to:
                clientSocket, clientAddress = serverSocket.accept()

                strPath = getPathFromRequest( str( clientSocket.recv( 1024 ) ) ) # read maximal 1024 bytes
                
                # print( "Path: ", strPath )
                
                match = PATTERN_JOYSTICK.match( strPath )
            
                if match :
                    fGear  = float(match.group( 1 )) # x
                    fSpeed = float(match.group( 2 )) # y

                    # Here You have gear in[-1;1] and speed in [-1;1].
                    # Change this for Your needs.
                    print( "Set: Gear = {}, speed = {}".format( fGear, fSpeed ) )
   
                    motorL.setSpeed( fSpeed + fGear )
                    motorR.setSpeed( fSpeed - fGear )
        
                  
                    sendHttpHeader( "200 OK", "plain", clientSocket )
                    clientSocket.send( match.group( 1 ) + ";" + match.group( 2 ) )
                   
                elif strPath == "/" :
                    sendHttpHeader( "200 OK", "html", clientSocket )
                    sendFile( "/index.html", clientSocket )
                             
                elif strPath == "/default.css" :
                    sendHttpHeader( "200 OK", "css", clientSocket )
                    sendFile( "/default.css", clientSocket )

                elif strPath == "/default.js" :
                    sendHttpHeader( "200 OK", "javascript", clientSocket )
                    sendFile( "/default.js", clientSocket )
                             
                else:
                    sendHttpHeader( "404 Not Found", "html", clientSocket )
                    sendFile( "/error404.html", clientSocket )

            except Exception as _e:
                print( _e )

            finally:
                try   : clientSocket.close()
                except: pass

        # Do something in the "background":
        display.clear()
        display.circle( 0,0,6)
        display.fillCircle( int(fGear*25), -int(fSpeed*25), 4 )
        display.show()
        
except KeyboardInterrupt:
    pass # User has typed "Ctrl C"

finally:
    # Clean up:
    try   : serverSocket.close()
    except: pass

    try   : wlanAccessPoint.active( False )  
    except: pass

    motorR.deinit()
    motorL.deinit()

    import gc
    gc.collect()
# Out:
# ***Connection broken [Input/output error]
# You may need to reconnect
# Closing serial Serial<id=0x7f57607d1e20, open=True>(port='/dev/ttyUSB3', baudrate=115200, bytesize=8, parity='N', stopbits=1, timeout=0.5, xonxoff=False, rtscts=False, dsrdtr=False)
# Connecting to --port=/dev/ttyUSB4 --baud=115200
# Ready.
# 192.168.4.1
# .Set: Gear = 0.0, speed = 0.005
# Set: Gear = -0.03, speed = 0.394
# Set: Gear = -0.025, speed = 0.48
# Set: Gear = -0.02, speed = 0.53
# Set: Gear = -0.02, speed = 0.551
# Set: Gear = -0.02, speed = 0.556
# Set: Gear = -0.02, speed = 0.561
# Set: Gear = -0.02, speed = 0.556
# Set: Gear = -0.02, speed = 0.52
# Set: Gear = -0.02, speed = 0.495
# Set: Gear = -0.02, speed = 0.429
# Set: Gear = -0.03, speed = 0.354
# Set: Gear = -0.03, speed = 0.308
# Set: Gear = -0.04, speed = 0.268
# Set: Gear = -0.045, speed = 0.197
# Set: Gear = -0.061, speed = 0.121
# Set: Gear = -0.071, speed = 0.061
# Set: Gear = -0.081, speed = 0.005
# Set: Gear = -0.09099999, speed = -0.061
# Set: Gear = -0.101, speed = -0.116
# Set: Gear = -0.106, speed = -0.162
# Set: Gear = -0.106, speed = -0.227
# Set: Gear = -0.106, speed = -0.303
# Set: Gear = -0.106, speed = -0.343
# Set: Gear = -0.101, speed = -0.369
# Set: Gear = -0.101, speed = -0.394
# Set: Gear = -0.101, speed = -0.439
# Set: Gear = -0.101, speed = -0.48
# Set: Gear = -0.101, speed = -0.505
# Set: Gear = -0.101, speed = -0.52
# Set: Gear = -0.101, speed = -0.525
# Set: Gear = -0.106, speed = -0.53
# Set: Gear = -0.111, speed = -0.545
# Set: Gear = -0.116, speed = -0.571
# Set: Gear = -0.116, speed = -0.596
# Set: Gear = -0.116, speed = -0.606
# Set: Gear = -0.121, speed = -0.616
# Set: Gear = -0.121, speed = -0.636
# Set: Gear = -0.121, speed = -0.646
# Set: Gear = -0.121, speed = -0.657
# Set: Gear = -0.121, speed = -0.652
# Set: Gear = -0.106, speed = -0.576
# Set: Gear = -0.081, speed = -0.379
# Set: Gear = -0.051, speed = -0.283
# Set: Gear = 0.0, speed = -0.086
# Set: Gear = 0.01, speed = -0.03
# Set: Gear = 0.03, speed = 0.02
# Set: Gear = 0.045, speed = 0.061
# Set: Gear = 0.051, speed = 0.081
# Set: Gear = 0.051, speed = 0.09099999
# Set: Gear = 0.02, speed = 0.096
# Set: Gear = -0.212, speed = 0.152
# Set: Gear = -0.389, speed = 0.197
# Set: Gear = -0.515, speed = 0.212
# Set: Gear = -0.611, speed = 0.202
# Set: Gear = -0.657, speed = 0.202
# Set: Gear = -0.687, speed = 0.197
# Set: Gear = -0.722, speed = 0.192
# Set: Gear = -0.758, speed = 0.192
# Set: Gear = -0.798, speed = 0.192
# Set: Gear = -0.833, speed = 0.192
# Set: Gear = -0.854, speed = 0.192
# Set: Gear = -0.859, speed = 0.192
# Set: Gear = -0.843, speed = 0.192
# Set: Gear = -0.773, speed = 0.192
# Set: Gear = -0.646, speed = 0.192
# Set: Gear = -0.47, speed = 0.172
# Set: Gear = -0.242, speed = 0.146
# Set: Gear = -0.061, speed = 0.096
# Set: Gear = -0.02, speed = 0.076
# Set: Gear = 0.071, speed = 0.045
# Set: Gear = 0.187, speed = 0.03
# Set: Gear = 0.318, speed = 0.02
# Set: Gear = 0.399, speed = 0.02
# Set: Gear = 0.475, speed = 0.03
# Set: Gear = 0.545, speed = 0.04
# Set: Gear = 0.591, speed = 0.051
# Set: Gear = 0.636, speed = 0.061
# Set: Gear = 0.672, speed = 0.061
# Set: Gear = 0.727, speed = 0.061
# Set: Gear = 0.818, speed = 0.06599999
# Set: Gear = 0.854, speed = 0.06599999
# Set: Gear = 0.889, speed = 0.061
# Set: Gear = 0.909, speed = 0.056
# Set: Gear = 0.929, speed = 0.051
# Set: Gear = 0.9440001, speed = 0.051
# Set: Gear = 0.939, speed = 0.051
# Set: Gear = 0.636, speed = 0.111
# Set: Gear = 0.192, speed = 0.081
# Set: Gear = 0.01, speed = 0.045
# Set: Gear = -0.04, speed = 0.035
# Set: Gear = -0.06599999, speed = 0.025
# Set: Gear = -0.096, speed = 0.015
# Set: Gear = -0.121, speed = 0.015
# Set: Gear = -0.126, speed = 0.015
# Set: Gear = -0.141, speed = 0.051
# Set: Gear = -0.172, speed = 0.126
# Set: Gear = -0.152, speed = 0.53
# Set: Gear = -0.121, speed = 0.677
# Set: Gear = -0.111, speed = 0.717
# Set: Gear = -0.071, speed = 0.813
# Set: Gear = -0.061, speed = 0.838
# Set: Gear = -0.056, speed = 0.848
# Set: Gear = -0.056, speed = 0.843
# Set: Gear = -0.061, speed = 0.788
# Set: Gear = -0.111, speed = 0.374
# Set: Gear = -0.207, speed = -0.141
# Set: Gear = -0.263, speed = -0.525
# Set: Gear = -0.263, speed = -0.965
# Set: Gear = -0.212, speed = -0.975
# Set: Gear = -0.212, speed = -0.98
# Set: Gear = -0.202, speed = -0.98
# Set: Gear = -0.197, speed = -0.98
# Set: Gear = -0.192, speed = -0.98
# Set: Gear = -0.192, speed = -0.98
# Set: Gear = -0.197, speed = -0.98
# Set: Gear = -0.263, speed = -0.965
# Set: Gear = -0.268, speed = -0.889
# Set: Gear = -0.268, speed = -0.864
# Set: Gear = -0.273, speed = -0.854
# Set: Gear = -0.354, speed = -0.803
# Set: Gear = -0.687, speed = 0.081
# Set: Gear = -0.707, speed = 0.288
# Set: Gear = -0.939, speed = 0.343
# Set: Gear = -0.955, speed = 0.303
# Set: Gear = -0.949, speed = 0.318
# Set: Gear = -0.9440001, speed = 0.328
# Set: Gear = -0.343, speed = 0.343
# Set: Gear = 0.545, speed = 0.141
# Set: Gear = 0.995, speed = 0.01
# Set: Gear = 1.0, speed = 0.0
# Set: Gear = 1.0, speed = -0.01
# Set: Gear = 1.0, speed = -0.015
# Set: Gear = 1.0, speed = -0.02
# Set: Gear = 0.283, speed = 0.0
# Set: Gear = -0.485, speed = -0.02
# Set: Gear = -0.566, speed = -0.025
# Set: Gear = -0.571, speed = -0.025
# Set: Gear = 0.02, speed = -0.01
# Set: Gear = 0.283, speed = -0.136
# Set: Gear = 0.308, speed = -0.162
# Set: Gear = 0.313, speed = -0.162
# Set: Gear = 0.384, speed = 0.308
# Set: Gear = 0.389, speed = 0.9190001
# Set: Gear = 0.369, speed = 0.929
# Set: Gear = 0.384, speed = 0.924
# Set: Gear = 0.278, speed = 0.283
# Set: Gear = 0.242, speed = -0.177
# Set: Gear = 0.227, speed = -0.515
# Set: Gear = 0.192, speed = -0.788
# Set: Gear = 0.192, speed = -0.859
# Set: Gear = 0.192, speed = -0.889
# Set: Gear = 0.192, speed = -0.909
# Set: Gear = 0.192, speed = -0.929
# Set: Gear = 0.192, speed = -0.98
# Set: Gear = 0.187, speed = -0.985
# Set: Gear = 0.182, speed = -0.985
# Set: Gear = 0.227, speed = -0.576
# Set: Gear = 0.293, speed = 0.131
# Set: Gear = 0.298, speed = 0.212
# Set: Gear = 0.242, speed = 0.222
# Set: Gear = -0.177, speed = 0.268
# Set: Gear = -0.657, speed = 0.253
# Set: Gear = -0.798, speed = 0.222
# Set: Gear = -0.899, speed = 0.207
# Set: Gear = -0.939, speed = 0.202
# Set: Gear = -0.955, speed = 0.202
# Set: Gear = -0.828, speed = 0.242
# Set: Gear = -0.09099999, speed = 0.354
# Set: Gear = 0.384, speed = 0.313
# Set: Gear = 0.985, speed = 0.177
# Set: Gear = 0.99, speed = 0.131
# Set: Gear = 0.99, speed = 0.126
# Set: Gear = 0.995, speed = 0.121
# Set: Gear = 0.9440001, speed = 0.121
# Set: Gear = 0.424, speed = 0.136
# Set: Gear = -0.09099999, speed = 0.192
# Set: Gear = -0.515, speed = 0.227
# Set: Gear = -0.788, speed = 0.227
# Set: Gear = -0.9190001, speed = 0.227
# Set: Gear = -0.975, speed = 0.227
# Set: Gear = -0.773, speed = 0.242
# Set: Gear = -0.04, speed = 0.197
# Set: Gear = 0.323, speed = 0.152
# Set: Gear = 0.616, speed = 0.061
# Set: Gear = 0.631, speed = 0.045
# Set: Gear = 0.429, speed = 0.02
# Set: Gear = 0.323, speed = 0.045
# Set: Gear = 0.303, speed = 0.162
# Set: Gear = 0.333, speed = 0.515
# Set: Gear = 0.369, speed = 0.909
# Set: Gear = 0.333, speed = 0.9440001
# Set: Gear = 0.308, speed = 0.949
# Set: Gear = 0.136, speed = 0.98
# Set: Gear = -0.081, speed = 0.662
# Set: Gear = -0.146, speed = 0.434
# Set: Gear = -0.162, speed = -0.061
# Set: Gear = -0.146, speed = -0.389
# Set: Gear = -0.111, speed = -0.747
# Set: Gear = -0.086, speed = -0.98
# Set: Gear = -0.086, speed = -0.995
# Set: Gear = -0.09099999, speed = -0.995
# Set: Gear = -0.096, speed = -0.995
# Set: Gear = -0.293, speed = -0.687
# Set: Gear = -0.303, speed = 0.222
# Set: Gear = -0.202, speed = 0.707
# Set: Gear = -0.182, speed = 0.818
# Set: Gear = -0.172, speed = 0.859
# Set: Gear = -0.162, speed = 0.909
# Set: Gear = -0.162, speed = 0.929
# Set: Gear = -0.172, speed = 0.899
# Set: Gear = -0.273, speed = 0.465
# Set: Gear = -0.308, speed = 0.202
# Set: Gear = -0.364, speed = 0.056
# Set: Gear = -0.419, speed = 0.015
# Set: Gear = -0.667, speed = 0.051
# Set: Gear = -0.818, speed = 0.101
# Set: Gear = -0.9440001, speed = 0.116
# Set: Gear = -0.995, speed = 0.116
# Set: Gear = -0.995, speed = 0.116
# Set: Gear = -0.995, speed = 0.116
# Set: Gear = -0.99, speed = 0.121
# Set: Gear = -0.99, speed = 0.136
# Set: Gear = -0.596, speed = 0.207
# Set: Gear = 0.09099999, speed = 0.298
# Set: Gear = 0.51, speed = 0.237
# Set: Gear = 0.682, speed = 0.177
# Set: Gear = 0.763, speed = 0.141
# Set: Gear = 0.788, speed = 0.131
# Set: Gear = 0.793, speed = 0.121
# Set: Gear = 0.778, speed = 0.111
# Set: Gear = 0.515, speed = 0.101
# Set: Gear = 0.09099999, speed = 0.152
# Set: Gear = -0.303, speed = 0.187
# Set: Gear = -0.364, speed = 0.192
# Set: Gear = -0.379, speed = 0.177
# Set: Gear = -0.374, speed = 0.152
# Set: Gear = -0.323, speed = 0.04
# Set: Gear = -0.253, speed = -0.056
# Set: Gear = -0.232, speed = -0.076
# Set: Gear = -0.232, speed = -0.071
# Set: Gear = -0.192, speed = 0.03
# Set: Gear = -0.162, speed = 0.051
# Set: Gear = -0.141, speed = 0.056
# Set: Gear = -0.126, speed = 0.03
# Set: Gear = -0.121, speed = 0.025
# .Set: Gear = 0.0, speed = 0.0
# ...............Set: Gear = 0.051, speed = 0.02
# Set: Gear = 0.217, speed = 0.03
# Set: Gear = 0.318, speed = 0.01
# Set: Gear = 0.399, speed = -0.01
# Set: Gear = 0.455, speed = -0.02
# Set: Gear = 0.51, speed = -0.02
# Set: Gear = 0.571, speed = -0.01
# Set: Gear = 0.596, speed = -0.01
# Set: Gear = 0.631, speed = -0.015
# Set: Gear = 0.677, speed = -0.015
# Set: Gear = 0.717, speed = -0.01
# Set: Gear = 0.742, speed = -0.01
# Set: Gear = 0.758, speed = -0.01
# Set: Gear = 0.768, speed = -0.01
# Set: Gear = 0.773, speed = -0.01
# Set: Gear = 0.737, speed = 0.0
# Set: Gear = 0.677, speed = 0.0
# Set: Gear = 0.54, speed = 0.0
# Set: Gear = 0.389, speed = 0.0
# Set: Gear = 0.258, speed = 0.0
# Set: Gear = 0.126, speed = 0.005
# Set: Gear = -0.04, speed = 0.01
# Set: Gear = -0.177, speed = 0.0
# Set: Gear = -0.288, speed = -0.005
# Set: Gear = -0.379, speed = -0.01
# Set: Gear = -0.53, speed = -0.01
# Set: Gear = -0.611, speed = -0.01
# Set: Gear = -0.712, speed = -0.01
# Set: Gear = -0.793, speed = -0.015
# Set: Gear = -0.833, speed = -0.02
# Set: Gear = -0.8690001, speed = -0.02
# Set: Gear = -0.884, speed = -0.02
# Set: Gear = -0.854, speed = -0.025
# Set: Gear = -0.823, speed = -0.03
# Set: Gear = -0.742, speed = -0.03
# Set: Gear = -0.571, speed = -0.051
# Set: Gear = -0.47, speed = -0.061
# Set: Gear = -0.354, speed = -0.076
# Set: Gear = -0.293, speed = -0.09099999
# Set: Gear = -0.258, speed = -0.101
# Set: Gear = -0.207, speed = -0.101
# Set: Gear = -0.167, speed = -0.106
# Set: Gear = -0.076, speed = -0.096
# Set: Gear = 0.0, speed = -0.086
# Set: Gear = 0.035, speed = -0.086
# Set: Gear = 0.035, speed = -0.081
# Set: Gear = 0.025, speed = -0.06599999
# Set: Gear = 0.015, speed = -0.01
# Set: Gear = 0.015, speed = 0.111
# Set: Gear = 0.015, speed = 0.242
# Set: Gear = 0.02, speed = 0.313
# Set: Gear = 0.03, speed = 0.384
# Set: Gear = 0.025, speed = 0.444
# Set: Gear = 0.015, speed = 0.525
# Set: Gear = 0.005, speed = 0.636
# Set: Gear = 0.0, speed = 0.712
# Set: Gear = 0.005, speed = 0.758
# Set: Gear = 0.005, speed = 0.808
# Set: Gear = 0.005, speed = 0.848
# Set: Gear = 0.005, speed = 0.859
# Set: Gear = 0.005, speed = 0.864
# Set: Gear = 0.005, speed = 0.8690001
# Set: Gear = 0.005, speed = 0.874
# .Set: Gear = 0.0, speed = 0.843
# Set: Gear = -0.005, speed = 0.798
# Set: Gear = -0.015, speed = 0.707
# Set: Gear = -0.035, speed = 0.606
# Set: Gear = -0.076, speed = 0.465
# Set: Gear = -0.126, speed = 0.192
# Set: Gear = -0.141, speed = -0.01
# Set: Gear = -0.131, speed = -0.172
# Set: Gear = -0.116, speed = -0.242
# Set: Gear = -0.116, speed = -0.318
# Set: Gear = -0.121, speed = -0.414
# Set: Gear = -0.136, speed = -0.495
# Set: Gear = -0.157, speed = -0.545
# Set: Gear = -0.177, speed = -0.606
# Set: Gear = -0.187, speed = -0.646
# Set: Gear = -0.197, speed = -0.667
# Set: Gear = -0.197, speed = -0.677
# Set: Gear = -0.207, speed = -0.687
# Set: Gear = -0.207, speed = -0.697
# Set: Gear = -0.207, speed = -0.707
# Set: Gear = -0.212, speed = -0.712
# Set: Gear = -0.217, speed = -0.717
# Set: Gear = -0.217, speed = -0.722
# Set: Gear = -0.217, speed = -0.727
# Set: Gear = -0.217, speed = -0.732
# Set: Gear = -0.212, speed = -0.758
# Set: Gear = -0.207, speed = -0.778
# Set: Gear = -0.207, speed = -0.793
# Set: Gear = -0.197, speed = -0.803
# Set: Gear = -0.187, speed = -0.808
# Set: Gear = -0.167, speed = -0.798
# Set: Gear = -0.157, speed = -0.768
# Set: Gear = -0.121, speed = -0.667
# Set: Gear = -0.106, speed = -0.571
# Set: Gear = -0.106, speed = -0.485
# Set: Gear = -0.106, speed = -0.424
# Set: Gear = -0.09099999, speed = -0.278
# Set: Gear = -0.061, speed = -0.061
# Set: Gear = -0.025, speed = 0.09099999
# Set: Gear = -0.01, speed = 0.227
# Set: Gear = 0.005, speed = 0.338
# Set: Gear = 0.01, speed = 0.424
# Set: Gear = 0.02, speed = 0.515
# Set: Gear = 0.025, speed = 0.556
# Set: Gear = 0.035, speed = 0.591
# Set: Gear = 0.04, speed = 0.636
# Set: Gear = 0.045, speed = 0.667
# Set: Gear = 0.045, speed = 0.672
# Set: Gear = 0.045, speed = 0.687
# Set: Gear = 0.06599999, speed = 0.722
# Set: Gear = 0.071, speed = 0.742
# Set: Gear = 0.071, speed = 0.758
# Set: Gear = 0.06599999, speed = 0.773
# Set: Gear = 0.035, speed = 0.818
# Set: Gear = 0.025, speed = 0.838
# Set: Gear = 0.02, speed = 0.838
# Set: Gear = 0.005, speed = 0.803
# Set: Gear = -0.01, speed = 0.717
# Set: Gear = -0.045, speed = 0.5809999
# Set: Gear = -0.086, speed = 0.389
# Set: Gear = -0.116, speed = 0.222
# Set: Gear = -0.177, speed = -0.051
# Set: Gear = -0.207, speed = -0.258
# Set: Gear = -0.222, speed = -0.399
# Set: Gear = -0.242, speed = -0.556
# Set: Gear = -0.258, speed = -0.687
# Set: Gear = -0.268, speed = -0.768
# Set: Gear = -0.278, speed = -0.798
# Set: Gear = -0.283, speed = -0.828
# Set: Gear = -0.288, speed = -0.843
# Set: Gear = -0.288, speed = -0.848
# Set: Gear = -0.288, speed = -0.854
# Set: Gear = -0.288, speed = -0.859
# Set: Gear = -0.288, speed = -0.854
# Set: Gear = -0.288, speed = -0.848
# Set: Gear = -0.288, speed = -0.843
# Set: Gear = -0.288, speed = -0.823
# Set: Gear = -0.278, speed = -0.732
# Set: Gear = -0.268, speed = -0.646
# Set: Gear = -0.263, speed = -0.545
# Set: Gear = -0.258, speed = -0.374
# Set: Gear = -0.242, speed = -0.157
# Set: Gear = -0.212, speed = 0.086
# Set: Gear = -0.187, speed = 0.227
# Set: Gear = -0.152, speed = 0.404
# Set: Gear = -0.09099999, speed = 0.606
# Set: Gear = -0.03, speed = 0.778
# Set: Gear = 0.005, speed = 0.909
# Set: Gear = 0.02, speed = 0.9700001
# Set: Gear = 0.025, speed = 0.99
# Set: Gear = 0.025, speed = 1.0
# Set: Gear = 0.025, speed = 0.995
# Set: Gear = 0.025, speed = 0.9700001
# Set: Gear = 0.015, speed = 0.859
# Set: Gear = -0.01, speed = 0.641
# Set: Gear = -0.06599999, speed = 0.348
# Set: Gear = -0.09099999, speed = 0.131
# Set: Gear = -0.136, speed = -0.283
# Set: Gear = -0.131, speed = -0.556
# Set: Gear = -0.116, speed = -0.788
# Set: Gear = -0.116, speed = -0.899
# Set: Gear = -0.131, speed = -0.9599999
# Set: Gear = -0.141, speed = -0.9700001
# Set: Gear = -0.157, speed = -0.939
# Set: Gear = -0.157, speed = -0.899
# Set: Gear = -0.126, speed = -0.687
# Set: Gear = -0.086, speed = -0.399
# Set: Gear = -0.045, speed = -0.162
# Set: Gear = -0.01, speed = 0.056
# Set: Gear = 0.035, speed = 0.293
# Set: Gear = 0.051, speed = 0.348
# Set: Gear = 0.025, speed = 0.303
# Set: Gear = -0.035, speed = 0.111
# Set: Gear = -0.09099999, speed = 0.025
# Set: Gear = -0.232, speed = 0.0
# Set: Gear = -0.449, speed = 0.035
# Set: Gear = -0.747, speed = 0.045
# Set: Gear = -0.9440001, speed = 0.051
# Set: Gear = -1.0, speed = 0.061
# Set: Gear = -1.0, speed = 0.06599999
# Set: Gear = -0.985, speed = 0.071
# Set: Gear = -0.818, speed = 0.081
# Set: Gear = -0.551, speed = 0.09099999
# Set: Gear = -0.303, speed = 0.081
# Set: Gear = -0.035, speed = 0.061
# Set: Gear = 0.379, speed = 0.015
# Set: Gear = 0.652, speed = -0.01
# Set: Gear = 0.803, speed = -0.03
# Set: Gear = 0.874, speed = -0.03
# Set: Gear = 0.884, speed = -0.025
# Set: Gear = 0.889, speed = -0.025
# Set: Gear = 0.848, speed = -0.01
# Set: Gear = 0.813, speed = 0.0
# Set: Gear = 0.763, speed = 0.01
# Set: Gear = 0.672, speed = 0.01
# Set: Gear = 0.475, speed = 0.0
# Set: Gear = 0.333, speed = 0.005
# Set: Gear = 0.217, speed = 0.015
# Set: Gear = 0.146, speed = 0.02
# Set: Gear = 0.106, speed = 0.035
# Set: Gear = 0.086, speed = 0.045
# Set: Gear = 0.061, speed = 0.071
# Set: Gear = 0.015, speed = 0.116
# Set: Gear = -0.025, speed = 0.182
# Set: Gear = -0.086, speed = 0.333
# Set: Gear = -0.106, speed = 0.485
# Set: Gear = -0.111, speed = 0.646
# Set: Gear = -0.106, speed = 0.717
# Set: Gear = -0.096, speed = 0.758
# Set: Gear = -0.096, speed = 0.763
# Set: Gear = -0.096, speed = 0.727
# Set: Gear = -0.101, speed = 0.652
# Set: Gear = -0.141, speed = 0.389
# Set: Gear = -0.177, speed = 0.187
# Set: Gear = -0.197, speed = -0.015
# Set: Gear = -0.207, speed = -0.212
# Set: Gear = -0.212, speed = -0.409
# Set: Gear = -0.212, speed = -0.576
# Set: Gear = -0.207, speed = -0.702
# Set: Gear = -0.207, speed = -0.808
# Set: Gear = -0.207, speed = -0.884
# Set: Gear = -0.212, speed = -0.899
# Set: Gear = -0.217, speed = -0.909
# Set: Gear = -0.227, speed = -0.859
# Set: Gear = -0.227, speed = -0.707
# Set: Gear = -0.217, speed = -0.495
# Set: Gear = -0.197, speed = -0.333
# Set: Gear = -0.167, speed = -0.086
# Set: Gear = -0.126, speed = 0.071
# Set: Gear = -0.09099999, speed = 0.268
# Set: Gear = -0.06599999, speed = 0.389
# Set: Gear = -0.025, speed = 0.551
# Set: Gear = 0.0, speed = 0.717
# Set: Gear = 0.015, speed = 0.808
# Set: Gear = 0.035, speed = 0.879
# Set: Gear = 0.035, speed = 0.884
# Set: Gear = 0.025, speed = 0.833
# Set: Gear = -0.005, speed = 0.667
# Set: Gear = -0.06599999, speed = 0.247
# Set: Gear = -0.09099999, speed = -0.056
# Set: Gear = -0.106, speed = -0.434
# Set: Gear = -0.116, speed = -0.374
# Set: Gear = -0.116, speed = -0.283
# Set: Gear = -0.111, speed = -0.157
# Set: Gear = -0.096, speed = 0.035
# Set: Gear = -0.071, speed = 0.212
# Set: Gear = -0.06599999, speed = 0.247
# Set: Gear = -0.06599999, speed = 0.253
# Set: Gear = -0.116, speed = 0.187
# Set: Gear = -0.217, speed = 0.09099999
# Set: Gear = -0.359, speed = 0.01
# Set: Gear = -0.5809999, speed = -0.015
# Set: Gear = -0.727, speed = -0.005
# Set: Gear = -0.843, speed = -0.005
# Set: Gear = -0.924, speed = -0.005
# Set: Gear = -0.955, speed = -0.005
# Set: Gear = -0.924, speed = 0.0
# Set: Gear = -0.742, speed = -0.005
# Set: Gear = -0.49, speed = -0.005
# Set: Gear = -0.217, speed = -0.025
# Set: Gear = 0.02, speed = -0.045
# Set: Gear = 0.247, speed = -0.071
# Set: Gear = 0.535, speed = -0.096
# Set: Gear = 0.672, speed = -0.101
# Set: Gear = 0.808, speed = -0.106
# Set: Gear = 0.828, speed = -0.106
# Set: Gear = 0.793, speed = -0.116
# Set: Gear = 0.626, speed = -0.126
# Set: Gear = 0.354, speed = -0.106
# Set: Gear = 0.172, speed = -0.086
# Set: Gear = 0.02, speed = 0.025
# Set: Gear = -0.045, speed = 0.227
# Set: Gear = -0.056, speed = 0.389
# Set: Gear = -0.045, speed = 0.611
# Set: Gear = -0.03, speed = 0.697
# Set: Gear = -0.01, speed = 0.768
# Set: Gear = -0.005, speed = 0.778
# Set: Gear = -0.005, speed = 0.783
# Set: Gear = 0.0, speed = 0.783
# Set: Gear = 0.01, speed = 0.793
# Set: Gear = 0.025, speed = 0.803
# Set: Gear = 0.03, speed = 0.768
# Set: Gear = 0.015, speed = 0.662
# Set: Gear = -0.015, speed = 0.47
# Set: Gear = -0.045, speed = 0.323
# Set: Gear = -0.071, speed = 0.167
# Set: Gear = -0.106, speed = -0.01
# Set: Gear = -0.152, speed = -0.237
# Set: Gear = -0.197, speed = -0.46
# Set: Gear = -0.222, speed = -0.611
# Set: Gear = -0.237, speed = -0.712
# Set: Gear = -0.247, speed = -0.793
# Set: Gear = -0.258, speed = -0.874
# Set: Gear = -0.258, speed = -0.909
# Set: Gear = -0.258, speed = -0.924
# Set: Gear = -0.258, speed = -0.929
# Set: Gear = -0.258, speed = -0.934
# Set: Gear = -0.263, speed = -0.9139999
# Set: Gear = -0.227, speed = -0.672
# Set: Gear = -0.157, speed = -0.293
# Set: Gear = -0.106, speed = -0.051
# Set: Gear = -0.056, speed = 0.177
# Set: Gear = -0.01, speed = 0.379
# Set: Gear = 0.025, speed = 0.5809999
# Set: Gear = 0.045, speed = 0.697
# Set: Gear = 0.045, speed = 0.712
# Set: Gear = 0.045, speed = 0.667
# Set: Gear = 0.035, speed = 0.54
# Set: Gear = 0.015, speed = 0.263
# Set: Gear = -0.02, speed = -0.06599999
# Set: Gear = -0.035, speed = -0.283
# Set: Gear = -0.025, speed = -0.323
# Set: Gear = -0.02, speed = -0.177
# Set: Gear = -0.136, speed = 0.025
# Set: Gear = -0.389, speed = 0.061
# Set: Gear = -0.586, speed = 0.056
# Set: Gear = -0.727, speed = 0.071
# Set: Gear = -0.803, speed = 0.086
# Set: Gear = -0.813, speed = 0.086
# Set: Gear = -0.783, speed = 0.076
# Set: Gear = -0.682, speed = 0.076
# Set: Gear = -0.566, speed = 0.086
# Set: Gear = -0.374, speed = 0.076
# Set: Gear = -0.01, speed = 0.056
# Set: Gear = 0.369, speed = 0.03
# Set: Gear = 0.54, speed = 0.015
# Set: Gear = 0.571, speed = 0.01
# Set: Gear = 0.308, speed = -0.03
# Set: Gear = 0.076, speed = -0.076
# Set: Gear = -0.187, speed = -0.076
# Set: Gear = -0.192, speed = 0.283
# Set: Gear = -0.116, speed = 0.641
# Set: Gear = -0.051, speed = 0.818
# Set: Gear = -0.06599999, speed = 0.535
# Set: Gear = -0.136, speed = -0.076
# Set: Gear = -0.197, speed = -0.657
# Set: Gear = -0.227, speed = -0.884
# Set: Gear = -0.232, speed = -0.9139999
# Set: Gear = -0.227, speed = -0.561
# Set: Gear = -0.177, speed = -0.111
# Set: Gear = -0.116, speed = 0.318
# Set: Gear = -0.056, speed = 0.631
# Set: Gear = -0.005, speed = 0.813
# Set: Gear = 0.01, speed = 0.813
# Set: Gear = -0.04, speed = 0.52
# Set: Gear = -0.081, speed = 0.101
# Set: Gear = -0.116, speed = -0.278
# Set: Gear = -0.146, speed = -0.616
# Set: Gear = -0.146, speed = -0.641
# Set: Gear = -0.06599999, speed = -0.359
# Set: Gear = 0.111, speed = 0.035
# Set: Gear = 0.288, speed = 0.111
# Set: Gear = 0.54, speed = 0.02
# Set: Gear = 0.712, speed = -0.076
# Set: Gear = 0.712, speed = -0.096
# Set: Gear = 0.439, speed = -0.101
# Set: Gear = -0.09099999, speed = -0.086
# Set: Gear = -0.404, speed = -0.051
# Set: Gear = -0.667, speed = -0.015
# Set: Gear = -0.864, speed = 0.015
# Set: Gear = -0.995, speed = 0.03
# Set: Gear = -1.0, speed = 0.035
# Set: Gear = -0.985, speed = 0.045
# Set: Gear = -0.722, speed = 0.025
# Set: Gear = -0.389, speed = 0.025
# Set: Gear = -0.177, speed = 0.03
# Set: Gear = 0.136, speed = 0.025
# Set: Gear = 0.429, speed = -0.005
# Set: Gear = 0.687, speed = -0.051
# Set: Gear = 0.904, speed = -0.086
# Set: Gear = 0.995, speed = -0.106
# Set: Gear = 0.995, speed = -0.116
# Set: Gear = 0.99, speed = -0.126
# Set: Gear = 0.934, speed = -0.126
# Set: Gear = 0.702, speed = -0.131
# Set: Gear = 0.409, speed = -0.162
# Set: Gear = 0.131, speed = -0.197
# Set: Gear = -0.071, speed = -0.197
# Set: Gear = -0.187, speed = -0.146
# Set: Gear = -0.237, speed = -0.005
# Set: Gear = -0.232, speed = 0.222
# Set: Gear = -0.187, speed = 0.49
# Set: Gear = -0.136, speed = 0.722
# Set: Gear = -0.061, speed = 0.965
# Set: Gear = -0.02, speed = 1.0
# Set: Gear = 0.01, speed = 1.0
# Set: Gear = 0.015, speed = 1.0
# Set: Gear = 0.02, speed = 0.823
# Set: Gear = -0.035, speed = 0.343
# Set: Gear = -0.076, speed = -0.111
# Set: Gear = -0.106, speed = -0.611
# Set: Gear = -0.101, speed = -0.884
# Set: Gear = -0.086, speed = -0.995
# Set: Gear = -0.09099999, speed = -0.995
# Set: Gear = -0.086, speed = -0.894
# Set: Gear = -0.04, speed = -0.389
# Set: Gear = 0.04, speed = 0.111
# Set: Gear = 0.141, speed = 0.5809999
# Set: Gear = 0.192, speed = 0.768
# Set: Gear = 0.217, speed = 0.889
# Set: Gear = 0.212, speed = 0.859
# Set: Gear = 0.146, speed = 0.485
# Set: Gear = 0.061, speed = 0.121
# Set: Gear = 0.005, speed = -0.227
# Set: Gear = -0.03, speed = -0.52
# Set: Gear = -0.056, speed = -0.753
# Set: Gear = -0.086, speed = -0.884
# Set: Gear = -0.121, speed = -0.848
# Set: Gear = -0.152, speed = -0.621
# Set: Gear = -0.182, speed = -0.308
# Set: Gear = -0.187, speed = -0.051
# Set: Gear = -0.172, speed = 0.247
# Set: Gear = -0.136, speed = 0.52
# Set: Gear = -0.076, speed = 0.747
# Set: Gear = -0.025, speed = 0.899
# Set: Gear = 0.005, speed = 0.965
# Set: Gear = 0.02, speed = 0.975
# Set: Gear = 0.045, speed = 0.889
# Set: Gear = 0.056, speed = 0.692
# Set: Gear = 0.045, speed = 0.293
# Set: Gear = 0.025, speed = 0.0
# Set: Gear = -0.005, speed = -0.268
# Set: Gear = -0.045, speed = -0.616
# Set: Gear = -0.061, speed = -0.833
# Set: Gear = -0.076, speed = -0.995
# Set: Gear = -0.076, speed = -0.995
# Set: Gear = -0.086, speed = -0.995
# Set: Gear = -0.096, speed = -0.995
# Set: Gear = -0.086, speed = -0.884
# Set: Gear = -0.035, speed = -0.429
# Set: Gear = 0.005, speed = -0.172
# Set: Gear = 0.06599999, speed = 0.172
# Set: Gear = 0.111, speed = 0.333
# Set: Gear = 0.086, speed = 0.263
# Set: Gear = -0.136, speed = 0.01
# Set: Gear = -0.424, speed = -0.035
# Set: Gear = -0.753, speed = -0.015
# Set: Gear = -0.9139999, speed = 0.005
# Set: Gear = -0.995, speed = 0.03
# Set: Gear = -1.0, speed = 0.045
# Set: Gear = -1.0, speed = 0.06599999
# Set: Gear = -0.682, speed = 0.096
# Set: Gear = -0.268, speed = 0.09099999
# Set: Gear = 0.222, speed = 0.056
# Set: Gear = 0.545, speed = 0.035
# Set: Gear = 0.904, speed = 0.03
# Set: Gear = 1.0, speed = 0.02
# Set: Gear = 1.0, speed = 0.005
# Set: Gear = 1.0, speed = 0.0
# Set: Gear = 1.0, speed = -0.005
# Set: Gear = 0.99, speed = -0.01
# Set: Gear = 0.854, speed = -0.02
# Set: Gear = 0.621, speed = -0.025
# Set: Gear = 0.258, speed = -0.035
# Set: Gear = 0.015, speed = -0.035
# Set: Gear = -0.187, speed = -0.02
# Set: Gear = -0.434, speed = -0.005
# Set: Gear = -0.621, speed = 0.005
# Set: Gear = -0.788, speed = 0.025
# Set: Gear = -0.909, speed = 0.04
# Set: Gear = -1.0, speed = 0.06599999
# Set: Gear = -0.995, speed = 0.081
# Set: Gear = -0.995, speed = 0.09099999
# Set: Gear = -0.995, speed = 0.086
# Set: Gear = -0.854, speed = 0.025
# Set: Gear = -0.51, speed = -0.035
# Set: Gear = -0.207, speed = -0.056
# Set: Gear = -0.076, speed = -0.005
# Set: Gear = 0.005, speed = 0.106
# Set: Gear = 0.035, speed = 0.247
# Set: Gear = 0.035, speed = 0.46
# Set: Gear = 0.03, speed = 0.707
# Set: Gear = 0.035, speed = 0.838
# Set: Gear = 0.045, speed = 0.965
# Set: Gear = 0.051, speed = 1.0
# Set: Gear = 0.045, speed = 1.0
# Set: Gear = 0.0, speed = 0.768
# Set: Gear = -0.061, speed = 0.49
# Set: Gear = -0.106, speed = 0.197
# Set: Gear = -0.136, speed = -0.106
# Set: Gear = -0.146, speed = -0.409
# Set: Gear = -0.136, speed = -0.707
# Set: Gear = -0.116, speed = -0.859
# Set: Gear = -0.071, speed = -0.995
# Set: Gear = -0.051, speed = -1.0
# Set: Gear = -0.04, speed = -1.0
# Set: Gear = -0.045, speed = -0.763
# Set: Gear = -0.03, speed = -0.475
# Set: Gear = 0.005, speed = -0.177
# Set: Gear = 0.035, speed = 0.06599999
# Set: Gear = 0.045, speed = 0.182
# Set: Gear = 0.025, speed = 0.207
# Set: Gear = -0.081, speed = 0.167
# Set: Gear = -0.247, speed = 0.106
# Set: Gear = -0.505, speed = 0.086
# Set: Gear = -0.803, speed = 0.071
# Set: Gear = -1.0, speed = 0.06599999
# Set: Gear = -0.995, speed = 0.071
# Set: Gear = -0.939, speed = 0.09099999
# Set: Gear = -0.5809999, speed = 0.056
# Set: Gear = -0.258, speed = 0.005
# Set: Gear = 0.318, speed = -0.056
# Set: Gear = 0.662, speed = -0.076
# Set: Gear = 0.727, speed = -0.086
# Set: Gear = 0.672, speed = -0.06599999
# Set: Gear = 0.52, speed = -0.015
# Set: Gear = 0.273, speed = 0.005
# Set: Gear = 0.035, speed = -0.005
# Set: Gear = -0.177, speed = -0.015
# Set: Gear = -0.232, speed = 0.0
# Set: Gear = -0.217, speed = 0.071
# Set: Gear = -0.207, speed = -0.005
# Set: Gear = -0.273, speed = -0.192
# Set: Gear = -0.273, speed = -0.106
# Set: Gear = -0.247, speed = 0.04
# Set: Gear = -0.212, speed = 0.06599999
# Set: Gear = -0.157, speed = -0.025
# Set: Gear = -0.136, speed = -0.212
# Set: Gear = -0.197, speed = -0.434
# Set: Gear = -0.227, speed = -0.359
# Set: Gear = -0.212, speed = -0.167
# Set: Gear = -0.187, speed = 0.02
# Set: Gear = -0.157, speed = 0.207
# Set: Gear = -0.121, speed = 0.389
# Set: Gear = -0.076, speed = 0.54
# Set: Gear = -0.056, speed = 0.662
# Set: Gear = -0.035, speed = 0.717
# Set: Gear = -0.035, speed = 0.722
# Set: Gear = -0.035, speed = 0.662
# Set: Gear = -0.035, speed = 0.561
# Set: Gear = -0.045, speed = 0.449
# Set: Gear = -0.076, speed = 0.268
# Set: Gear = -0.126, speed = 0.071
# Set: Gear = -0.157, speed = -0.101
# Set: Gear = -0.197, speed = -0.399
# Set: Gear = -0.202, speed = -0.621
# Set: Gear = -0.187, speed = -0.732
# Set: Gear = -0.157, speed = -0.874
# Set: Gear = -0.157, speed = -0.924
# Set: Gear = -0.141, speed = -0.848
# Set: Gear = -0.126, speed = -0.636
# Set: Gear = -0.116, speed = -0.48
# Set: Gear = -0.116, speed = -0.318
# Set: Gear = -0.106, speed = 0.005
# Set: Gear = -0.06599999, speed = 0.273
# Set: Gear = -0.025, speed = 0.48
# Set: Gear = -0.01, speed = 0.545
# Set: Gear = -0.01, speed = 0.556
# Set: Gear = -0.02, speed = 0.52
# Set: Gear = -0.035, speed = 0.399
# Set: Gear = -0.051, speed = 0.207
# Set: Gear = -0.076, speed = -0.025
# Set: Gear = -0.116, speed = -0.313
# Set: Gear = -0.131, speed = -0.48
# Set: Gear = -0.136, speed = -0.591
# Set: Gear = -0.131, speed = -0.657
# Set: Gear = -0.121, speed = -0.611
# Set: Gear = -0.101, speed = -0.475
# Set: Gear = -0.06599999, speed = -0.232
# Set: Gear = -0.025, speed = -0.005
# Set: Gear = 0.015, speed = 0.141
# Set: Gear = 0.076, speed = 0.359
# Set: Gear = 0.116, speed = 0.495
# Set: Gear = 0.131, speed = 0.601
# Set: Gear = 0.136, speed = 0.652
# Set: Gear = 0.136, speed = 0.682
# Set: Gear = 0.136, speed = 0.687
# Set: Gear = 0.136, speed = 0.682
# Set: Gear = 0.126, speed = 0.631
# Set: Gear = 0.096, speed = 0.47
# Set: Gear = 0.035, speed = 0.237
# Set: Gear = -0.025, speed = -0.106
# Set: Gear = -0.056, speed = -0.399
# Set: Gear = -0.076, speed = -0.566
# Set: Gear = -0.116, speed = -0.833
# Set: Gear = -0.131, speed = -0.854
# Set: Gear = -0.136, speed = -0.697
# Set: Gear = -0.101, speed = -0.293
# Set: Gear = -0.071, speed = 0.025
# Set: Gear = -0.157, speed = 0.076
# Set: Gear = -0.449, speed = 0.015
# Set: Gear = -0.652, speed = 0.005
# Set: Gear = -0.823, speed = 0.02
# Set: Gear = -0.9139999, speed = 0.045
# Set: Gear = -0.793, speed = 0.06599999
# Set: Gear = -0.535, speed = 0.045
# Set: Gear = -0.04, speed = -0.005
# Set: Gear = 0.323, speed = -0.035
# Set: Gear = 0.621, speed = -0.04
# Set: Gear = 0.788, speed = -0.051
# Set: Gear = 0.687, speed = -0.081
# Set: Gear = 0.429, speed = -0.126
# Set: Gear = 0.162, speed = -0.146
# Set: Gear = -0.051, speed = -0.126
# Set: Gear = -0.182, speed = 0.01
# Set: Gear = -0.212, speed = 0.202
# Set: Gear = -0.187, speed = 0.434
# Set: Gear = -0.111, speed = 0.773
# Set: Gear = -0.076, speed = 0.874
# Set: Gear = -0.076, speed = 0.889
# Set: Gear = -0.06599999, speed = 0.859
# Set: Gear = -0.071, speed = 0.712
# Set: Gear = -0.106, speed = 0.47
# Set: Gear = -0.116, speed = 0.268
# Set: Gear = -0.101, speed = 0.04
# Set: Gear = -0.096, speed = -0.227
# Set: Gear = -0.101, speed = -0.5809999
# Set: Gear = -0.106, speed = -0.818
# Set: Gear = -0.126, speed = -0.9440001
# Set: Gear = -0.131, speed = -0.904
# Set: Gear = -0.126, speed = -0.783
# Set: Gear = -0.116, speed = -0.586
# Set: Gear = -0.081, speed = -0.288
# Set: Gear = -0.035, speed = 0.056
# Set: Gear = 0.035, speed = 0.394
# Set: Gear = 0.076, speed = 0.571
# Set: Gear = 0.111, speed = 0.682
# Set: Gear = 0.136, speed = 0.763
# Set: Gear = 0.136, speed = 0.773
# Set: Gear = 0.116, speed = 0.657
# Set: Gear = 0.056, speed = 0.47
# Set: Gear = -0.056, speed = 0.121
# Set: Gear = -0.136, speed = -0.167
# Set: Gear = -0.172, speed = -0.439
# Set: Gear = -0.177, speed = -0.551
# Set: Gear = -0.177, speed = -0.611
# Set: Gear = -0.177, speed = -0.621
# Set: Gear = -0.177, speed = -0.53
# Set: Gear = -0.167, speed = -0.273
# Set: Gear = -0.152, speed = -0.005
# Set: Gear = -0.126, speed = 0.177
# Set: Gear = -0.121, speed = 0.197
# Set: Gear = 0.0, speed = 0.0
# ................................................

# %%
#%serialconnect --port=COM3 --baud=115200 # für Windows
%serialconnect # für Linux

from machine import PWM, Pin
import time


pin = PWM( Pin(13, Pin.OUT), freq=1000, duty=1000)  # 25 HelTec, 13 Croduino

for iDuty in range( 1000, -1, -1 ):
    pin.duty(iDuty)
    time.sleep( 0.005 )

pin.deinit() # falls der Pin im selbem Porgramm noch mal als on/off- Pin verwendet werden soll.
    
print( "DONE." )
# Out:
# Connecting to --port=/dev/ttyUSB3 --baud=115200
# Ready.
# .DONE.

# %%
%serialconnect

from motor import Motor

motorL = Motor( 12, 13,
    iFrequency     = 300,
    iDutyMinLeft   = 220,
    iDutyMaxLeft   = 1023,
    iDutyMinRight  = 220,
    iDutyMaxRight  = 1023,
    fSpeedMaxLeft  = -1.0,
    fSpeedMaxRight =  1.0 )

motorL.setSpeed( 1.0 )
# Out:
# Connecting to --port=/dev/ttyUSB3 --baud=115200
# Ready.

# %%
motorL.setSpeed(0               )
